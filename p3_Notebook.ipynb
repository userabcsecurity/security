# %% [markdown]
# # 3. part 1

# %%
### importing libraries

# %%
import pandas as pand
import numpy as nump
import matplotlib
import matplotlib.pyplot as plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
import pandas as pd
# %matplotlib inline
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#### importing dataset

# %%
data = pd.read_csv('D:/P3_Data.csv')

# %%
data.head()
# Out:
#        F1      F2      F3     F4       F5     F6        F7     F8       F9  \
# 0  271.78  -21.92      UK -10.80  1899.57  17.98 -21749.82  91.94   855.61
# 1  202.54   43.82     USA -16.94  1941.57  -9.16 -27668.04  93.50   975.44
# 2  220.26   88.90  Europe -18.76  2298.12 -18.38 -11548.56  65.16  1114.28
# 3  141.00  140.72  Europe -19.86  -133.32 -57.00 -16200.96 -14.00   910.12
# 4  165.04    2.74  Europe -21.34  3077.07 -20.50 -25683.06  29.08   216.24
#
#      F10  ...      F28     F29       F30   F31     F32     F33     F34  \
# 0  10.01  ...  2098.80  500.16  -6325.53  1.36  -33.14  177.34 -141.97
# 1   7.29  ...  1668.70  434.97  -6172.05  2.59  -58.87   87.48 -154.11
# 2  12.05  ...  2604.56  252.93 -10132.68  2.94  -40.89  271.00 -279.84
# 3   4.54  ...  2595.56  154.83  -7862.04  0.86 -117.03  201.66 -153.93
# 4  10.10  ...  1066.80  316.68  -6093.81  3.59  -63.84  211.82 -182.34
#
#       F35  F36   Target
# 0  101.52    5   189.03
# 1  623.22    6   187.17
# ...

# %%
data
# Out:
#           F1      F2      F3     F4       F5      F6        F7      F8  \
# 0     271.78  -21.92      UK -10.80  1899.57   17.98 -21749.82   91.94
# 1     202.54   43.82     USA -16.94  1941.57   -9.16 -27668.04   93.50
# 2     220.26   88.90  Europe -18.76  2298.12  -18.38 -11548.56   65.16
# 3     141.00  140.72  Europe -19.86  -133.32  -57.00 -16200.96  -14.00
# 4     165.04    2.74  Europe -21.34  3077.07  -20.50 -25683.06   29.08
# ...      ...     ...     ...    ...      ...     ...       ...     ...
# 1495  136.78 -118.70      UK -11.00 -2182.26   61.36 -28652.91  122.18
# 1496  237.54   22.46  Europe -14.26  3708.21  -13.08 -32394.33  128.58
# 1497  144.24    7.18     USA -19.48  3350.37  -42.80 -29448.90   35.42
# 1498  340.12  -72.58  Europe -17.18  -244.83  178.16 -23377.80  178.96
# 1499  182.82  -82.10  Europe -21.46  1489.38  136.48 -19995.87   93.32
#
#            F9    F10  ...      F28     F29       F30   F31     F32     F33  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 37 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      1500 non-null   float64
#  1   F2      1500 non-null   float64
#  2   F3      1500 non-null   object
#  3   F4      1500 non-null   float64
#  4   F5      1500 non-null   float64
#  5   F6      1500 non-null   float64
#  6   F7      1500 non-null   float64
#  7   F8      1500 non-null   float64
#  8   F9      1500 non-null   float64
#  9   F10     1500 non-null   float64
#  10  F11     1500 non-null   object
#  11  F12     1500 non-null   float64
#  12  F13     1500 non-null   float64
#  13  F14     1500 non-null   float64
#  14  F15     1500 non-null   float64
#  15  F16     1500 non-null   float64
#  16  F17     1500 non-null   float64
#  17  F18     1500 non-null   float64
#  18  F19     1500 non-null   float64
#  19  F20     1500 non-null   float64
# ...

# %%
### null value checking

# %%
data.isna().sum()
# Out:
# F1        0
# F2        0
# F3        0
# F4        0
# F5        0
# F6        0
# F7        0
# F8        0
# F9        0
# F10       0
# F11       0
# F12       0
# F13       0
# F14       0
# F15       0
# F16       0
# F17       0
# F18       0
# F19       0
# F20       0
# F21       0
# F22       0
# F23       0
# F24       0
# F25       0
# F26       0
# F27       0
# F28       0
# F29       0
# F30       0
# F31       0
# F32       0
# F33       0
# F34       0
# F35       0
# F36       0
# Target    0
# dtype: int64

# %%
## data preprocessing 
data = data.dropna()

# %%
print(data)
# Out:
#           F1      F2      F3     F4       F5      F6        F7      F8  \
# 0     271.78  -21.92      UK -10.80  1899.57   17.98 -21749.82   91.94
# 1     202.54   43.82     USA -16.94  1941.57   -9.16 -27668.04   93.50
# 2     220.26   88.90  Europe -18.76  2298.12  -18.38 -11548.56   65.16
# 3     141.00  140.72  Europe -19.86  -133.32  -57.00 -16200.96  -14.00
# 4     165.04    2.74  Europe -21.34  3077.07  -20.50 -25683.06   29.08
# ...      ...     ...     ...    ...      ...     ...       ...     ...
# 1495  136.78 -118.70      UK -11.00 -2182.26   61.36 -28652.91  122.18
# 1496  237.54   22.46  Europe -14.26  3708.21  -13.08 -32394.33  128.58
# 1497  144.24    7.18     USA -19.48  3350.37  -42.80 -29448.90   35.42
# 1498  340.12  -72.58  Europe -17.18  -244.83  178.16 -23377.80  178.96
# 1499  182.82  -82.10  Europe -21.46  1489.38  136.48 -19995.87   93.32
#
#            F9    F10  ...      F28     F29       F30   F31     F32     F33  \
# ...

# %%
data.isna().sum()
# Out:
# F1        0
# F2        0
# F3        0
# F4        0
# F5        0
# F6        0
# F7        0
# F8        0
# F9        0
# F10       0
# F11       0
# F12       0
# F13       0
# F14       0
# F15       0
# F16       0
# F17       0
# F18       0
# F19       0
# F20       0
# F21       0
# F22       0
# F23       0
# F24       0
# F25       0
# F26       0
# F27       0
# F28       0
# F29       0
# F30       0
# F31       0
# F32       0
# F33       0
# F34       0
# F35       0
# F36       0
# Target    0
# dtype: int64

# %%
data.dtypes
# Out:
# F1        float64
# F2        float64
# F3         object
# F4        float64
# F5        float64
# F6        float64
# F7        float64
# F8        float64
# F9        float64
# F10       float64
# F11        object
# F12       float64
# F13       float64
# F14       float64
# F15       float64
# F16       float64
# F17       float64
# F18       float64
# F19       float64
# F20       float64
# F21       float64
# F22       float64
# F23         int64
# F24       float64
# F25       float64
# F26       float64
# F27       float64
# F28       float64
# F29       float64
# F30       float64
# F31       float64
# F32       float64
# F33       float64
# F34       float64
# F35       float64
# F36         int64
# Target    float64
# dtype: object

# %%
data
# Out:
#           F1      F2      F3     F4       F5      F6        F7      F8  \
# 0     271.78  -21.92      UK -10.80  1899.57   17.98 -21749.82   91.94
# 1     202.54   43.82     USA -16.94  1941.57   -9.16 -27668.04   93.50
# 2     220.26   88.90  Europe -18.76  2298.12  -18.38 -11548.56   65.16
# 3     141.00  140.72  Europe -19.86  -133.32  -57.00 -16200.96  -14.00
# 4     165.04    2.74  Europe -21.34  3077.07  -20.50 -25683.06   29.08
# ...      ...     ...     ...    ...      ...     ...       ...     ...
# 1495  136.78 -118.70      UK -11.00 -2182.26   61.36 -28652.91  122.18
# 1496  237.54   22.46  Europe -14.26  3708.21  -13.08 -32394.33  128.58
# 1497  144.24    7.18     USA -19.48  3350.37  -42.80 -29448.90   35.42
# 1498  340.12  -72.58  Europe -17.18  -244.83  178.16 -23377.80  178.96
# 1499  182.82  -82.10  Europe -21.46  1489.38  136.48 -19995.87   93.32
#
#            F9    F10  ...      F28     F29       F30   F31     F32     F33  \
# ...

# %%
#### linear regression

# %%
data[["F3"]] = data[["F3"]].apply(lambda col:pd.Categorical(col).codes)

# %%
data
# Out:
#           F1      F2  F3     F4       F5      F6        F7      F8       F9  \
# 0     271.78  -21.92   2 -10.80  1899.57   17.98 -21749.82   91.94   855.61
# 1     202.54   43.82   3 -16.94  1941.57   -9.16 -27668.04   93.50   975.44
# 2     220.26   88.90   0 -18.76  2298.12  -18.38 -11548.56   65.16  1114.28
# 3     141.00  140.72   0 -19.86  -133.32  -57.00 -16200.96  -14.00   910.12
# 4     165.04    2.74   0 -21.34  3077.07  -20.50 -25683.06   29.08   216.24
# ...      ...     ...  ..    ...      ...     ...       ...     ...      ...
# 1495  136.78 -118.70   2 -11.00 -2182.26   61.36 -28652.91  122.18   931.96
# 1496  237.54   22.46   0 -14.26  3708.21  -13.08 -32394.33  128.58   405.60
# 1497  144.24    7.18   3 -19.48  3350.37  -42.80 -29448.90   35.42   253.94
# 1498  340.12  -72.58   0 -17.18  -244.83  178.16 -23377.80  178.96   683.61
# 1499  182.82  -82.10   0 -21.46  1489.38  136.48 -19995.87   93.32   482.76
#
# ...

# %%
data[["F11"]] = data[["F11"]].apply(lambda col:pd.Categorical(col).codes)

# %%
data
# Out:
#           F1      F2  F3     F4       F5      F6        F7      F8       F9  \
# 0     271.78  -21.92   2 -10.80  1899.57   17.98 -21749.82   91.94   855.61
# 1     202.54   43.82   3 -16.94  1941.57   -9.16 -27668.04   93.50   975.44
# 2     220.26   88.90   0 -18.76  2298.12  -18.38 -11548.56   65.16  1114.28
# 3     141.00  140.72   0 -19.86  -133.32  -57.00 -16200.96  -14.00   910.12
# 4     165.04    2.74   0 -21.34  3077.07  -20.50 -25683.06   29.08   216.24
# ...      ...     ...  ..    ...      ...     ...       ...     ...      ...
# 1495  136.78 -118.70   2 -11.00 -2182.26   61.36 -28652.91  122.18   931.96
# 1496  237.54   22.46   0 -14.26  3708.21  -13.08 -32394.33  128.58   405.60
# 1497  144.24    7.18   3 -19.48  3350.37  -42.80 -29448.90   35.42   253.94
# 1498  340.12  -72.58   0 -17.18  -244.83  178.16 -23377.80  178.96   683.61
# 1499  182.82  -82.10   0 -21.46  1489.38  136.48 -19995.87   93.32   482.76
#
# ...

# %%
from sklearn import datasets, linear_model, metrics

# %%
x=data.drop("Target", axis=1)

# %%
y=data["Target"]

# %%
x
# Out:
#           F1      F2  F3     F4       F5      F6        F7      F8       F9  \
# 0     271.78  -21.92   2 -10.80  1899.57   17.98 -21749.82   91.94   855.61
# 1     202.54   43.82   3 -16.94  1941.57   -9.16 -27668.04   93.50   975.44
# 2     220.26   88.90   0 -18.76  2298.12  -18.38 -11548.56   65.16  1114.28
# 3     141.00  140.72   0 -19.86  -133.32  -57.00 -16200.96  -14.00   910.12
# 4     165.04    2.74   0 -21.34  3077.07  -20.50 -25683.06   29.08   216.24
# ...      ...     ...  ..    ...      ...     ...       ...     ...      ...
# 1495  136.78 -118.70   2 -11.00 -2182.26   61.36 -28652.91  122.18   931.96
# 1496  237.54   22.46   0 -14.26  3708.21  -13.08 -32394.33  128.58   405.60
# 1497  144.24    7.18   3 -19.48  3350.37  -42.80 -29448.90   35.42   253.94
# 1498  340.12  -72.58   0 -17.18  -244.83  178.16 -23377.80  178.96   683.61
# 1499  182.82  -82.10   0 -21.46  1489.38  136.48 -19995.87   93.32   482.76
#
# ...

# %%
y
# Out:
# 0        189.03
# 1        187.17
# 2       1016.24
# 3       -141.18
# 4         33.17
#          ...
# 1495     794.82
# 1496    2599.94
# 1497    -171.98
# 1498     489.46
# 1499    3784.99
# Name: Target, Length: 1500, dtype: float64

# %%
#### splitting x and y into training and splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                    random_state=1)

# %%
### linear regression object

# %%
linearreg= linear_model.LinearRegression()

# %%
### training the model

# %%
linearreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#### regression cofficients

# %%
print('Coefficients: ', linearreg.coef_)
# Out:
# Coefficients:  [-2.31060109e-02 -2.75063694e-01 -3.11539681e+02  1.32942102e+00
#  -8.01096834e-03 -2.82453259e-03  7.18612108e-05  2.28772674e-01
#  -5.47163147e-02  2.05662797e+00 -8.63284831e+01  5.36626752e-01
#   6.46036637e+01 -1.75938726e-02 -7.35284270e-01 -3.11558200e-01
#   9.16934420e-03 -4.69833267e-02 -2.80521842e+00  5.80581087e-02
#  -8.49565756e-04  1.15434080e+00 -8.70511528e+01  4.97484531e-03
#  -2.28706014e-03 -7.01472442e-01  3.24388085e-02 -1.00381472e-01
#  -4.28844874e-02 -1.39444216e-02 -2.37991732e+01  1.28731433e-01
#   2.32786166e-01 -8.78404979e-01 -1.91820904e-01 -2.33921190e+02]

# %%
### printing score

# %%
y_pred=linearreg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred
# Out:
# array([ -877.95560104,  -657.75263377,  1929.69170225,  1687.78825901,
#         -456.56198748,   825.29880328,  2283.79856316,  -132.07534697,
#          375.43243994,   672.07835641,  2718.89861705,  1514.89210853,
#          638.81490518,   336.45570619,  1391.08003145,  2350.99253745,
#         1383.27054706,   -35.20643585,  1664.47952344,   846.58708728,
#          491.90727157,   983.18493825,   470.7953448 ,   708.28126952,
#          915.59274129,   960.17421647,  2104.68384984,  1045.901538  ,
#          703.74831421,  1177.61929585,  -629.74256293,  2452.26765044,
#         1739.58008773,   283.91327075,  2429.58939177,  3173.29189356,
#          942.25045649,   120.16454443,   470.33812151,  1423.30284367,
#          768.11565328,   612.61677008,  1531.14741234,  2103.2179452 ,
#          -85.30518443,   162.70353286,  1750.68889703,   955.5697609 ,
#         1440.60220096,  -268.48093809,  -638.44227333,   957.70522174,
# ...

# %%
y_test
# Out:
# 91      -112.93
# 75       -21.36
# 1264    2042.21
# 330     2360.34
# 1349    -158.71
#          ...
# 1094     829.85
# 1204     494.69
# 1130    1301.82
# 12       191.04
# 408     1954.93
# Name: Target, Length: 300, dtype: float64

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 618753.6209620159

# %%
print('score: {}'.format(linearreg.score(x_test, y_test)))
# Out:
# score: 0.5851495346724115

# %%
plt.style.use('fivethirtyeight')

# %%
plt.scatter(linearreg.predict(x_train), linearreg.predict(x_train) - y_train, color = "red", s = 10, label = 'Train data')

# %%
plt.scatter(linearreg.predict(x_test), linearreg.predict(x_test) - y_test,color = "green", s = 10, label = 'Test data')

# %%
### random forest regression

# %%
### import the regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
### creating the regressor object

# %%
randomregressor = RandomForestRegressor()

# %%
#### fitting the regresssor with x and y data

# %%
randomregressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred = randomregressor.predict(x_test)

# %%
y_pred
# Out:
# array([ -877.95560104,  -657.75263377,  1929.69170225,  1687.78825901,
#         -456.56198748,   825.29880328,  2283.79856316,  -132.07534697,
#          375.43243994,   672.07835641,  2718.89861705,  1514.89210853,
#          638.81490518,   336.45570619,  1391.08003145,  2350.99253745,
#         1383.27054706,   -35.20643585,  1664.47952344,   846.58708728,
#          491.90727157,   983.18493825,   470.7953448 ,   708.28126952,
#          915.59274129,   960.17421647,  2104.68384984,  1045.901538  ,
#          703.74831421,  1177.61929585,  -629.74256293,  2452.26765044,
#         1739.58008773,   283.91327075,  2429.58939177,  3173.29189356,
#          942.25045649,   120.16454443,   470.33812151,  1423.30284367,
#          768.11565328,   612.61677008,  1531.14741234,  2103.2179452 ,
#          -85.30518443,   162.70353286,  1750.68889703,   955.5697609 ,
#         1440.60220096,  -268.48093809,  -638.44227333,   957.70522174,
# ...

# %%
y_test
# Out:
# 91      -112.93
# 75       -21.36
# 1264    2042.21
# 330     2360.34
# 1349    -158.71
#          ...
# 1094     829.85
# 1204     494.69
# 1130    1301.82
# 12       191.04
# 408     1954.93
# Name: Target, Length: 300, dtype: float64

# %%
print('score: {}'.format(randomregressor.score(x_test, y_test)))
# Out:
# score: 0.6450078427996141

# %%
plt.scatter(randomregressor.predict(x_test), linearreg.predict(x_test) - y_test,color = "green", s = 10, label = 'Test data')

# %%
##### ridge regression

# %%
from sklearn.linear_model import Ridge

# %%
clf = Ridge(alpha=1.0)

# %%
clf.fit(x_train, y_train)
# Out:
# Ridge()

# %%
y_pred=clf.predict(x_test)

# %%
clf.score(x_test,y_test)
# Out:
# 0.5851317302637433

# %%
plt.scatter(clf.predict(x_test), linearreg.predict(x_test) - y_test,color = "green", s = 10, label = 'Test data')

# %% [markdown]
# # part II

# %%
#### dataset import

# %%
data = pd.read_csv('D:/P3_Test.csv')

# %%
data=data.drop("Target",axis=1)

# %%
data.isna().sum()
# Out:
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# F29    0
# F30    0
# F31    0
# F32    0
# F33    0
# F34    0
# F35    0
# F36    0
# dtype: int64

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# F1     0
# F2     0
# F3     0
# F4     0
# F5     0
# F6     0
# F7     0
# F8     0
# F9     0
# F10    0
# F11    0
# F12    0
# F13    0
# F14    0
# F15    0
# F16    0
# F17    0
# F18    0
# F19    0
# F20    0
# F21    0
# F22    0
# F23    0
# F24    0
# F25    0
# F26    0
# F27    0
# F28    0
# F29    0
# F30    0
# F31    0
# F32    0
# F33    0
# F34    0
# F35    0
# F36    0
# dtype: int64

# %%
data[["F3"]] = data[["F3"]].apply(lambda col:pd.Categorical(col).codes)

# %%
data[["F11"]] = data[["F11"]].apply(lambda col:pd.Categorical(col).codes)

# %%
y_pred_new=randomregressor.predict(data)

# %%
data["Target"]=y_pred_new

# %%
data
# Out:
#           F1      F2  F3     F4       F5      F6        F7      F8       F9  \
# 0     293.42  126.36   0 -23.90  3012.33 -196.64 -15368.82  112.52  1029.51
# 1     242.26   49.12   1 -17.56  2485.47    5.10 -38092.89   25.94   522.92
# 2     130.54   62.32   1 -27.34  1973.40    1.98 -21792.75   89.28   551.56
# 3     171.62  144.70   1 -20.70  2167.92  -20.82 -10528.14   91.22  1207.56
# 4     155.78 -202.92   1 -24.86  2657.28   17.24 -23577.09   75.84   425.77
# ...      ...     ...  ..    ...      ...     ...       ...     ...      ...
# 1495  283.66   20.72   3 -24.14  2058.24   96.78 -39055.41  159.54  1122.08
# 1496  185.44  -15.20   1 -19.70  2029.80  127.30 -31133.58   58.56   658.80
# 1497  134.28   35.72   2 -19.58  1999.17   -6.58  -9067.11   51.84  1211.30
# 1498  211.72   20.28   0 -18.54  1786.62  -42.66 -13774.95   72.30   439.74
# 1499  274.72   35.82   0 -22.88  3927.96   28.04 -26389.47   66.66   743.56
#
# ...

# %%
### converting data to csv

# %%
data.to_csv("D:/P3_Test_Predictions.csv")
